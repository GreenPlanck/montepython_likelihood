# %%
from cobaya import get_model

# %%
params = {'logA': 3.044,
 'n_s': 0.965,
 'h': 0.675,
 'omega_b': 0.02235,
 'omega_cdm': 0.120,
 'tau_reio': 0.0543,
         }

# %%
mode=get_model('actdr6.yaml',packages_path='/Users/zhiyulu/Documents/Science/Cosmology_data/ACT_dr6_likelihood')
#mode=get_model('actdr6.yaml',packages_path='/Users/zhiyulu/Documents/Science/Cosmology_packages/Likelihood/ACT_dr6_likelihood/act_dr6_lenslike/data/')
mode.logposterior(params)
# Out:
# [model] *WARNING* Ignored blocks/options: ['sampler', 'output']
# [classy] `classy` module loaded successfully from /Users/zhiyulu/Install/anaconda3/lib/python3.11/site-packages
# Loading ACT DR6 lensing likelihood v1.2...
# /Users/zhiyulu/Documents/Science/Cosmology_packages/Likelihood/act_dr6_lenslike-main/act_dr6_lenslike/act_dr6_lenslike.py:422: UserWarning: Hartlap correction to cinv: 0.9860935524652339
#   warnings.warn(f"Hartlap correction to cinv: {hartlap_correction}")
# LogPosterior(logpost=-4.328421987951323, logpriors=[2.7894037928589683], loglikes=array([-7.11782578]), derived=[2.0989031673191437e-09, 0.31384172488986367, 0.14299413590294416, 0.6860787971858595, 0.24529383108121505, 7.6847991943359375, 0.8112133154213543, 0.9873774040107316, 0.45445450366893936, 0.6071734057330297, 2.098903167319144, 1.8829033242359754, 13.785194922202777, 147.1192099219605], finite=False)

# %%
from act_dr6_lenslike import ACTDR6LensLike
# c = ACTDR6LensLike(packages_path='/Users/zhiyulu/Documents/Science/Cosmology_data/ACT_dr6_likelihood')
c = ACTDR6LensLike(
                   {'lens_only':True,
                    'stop_at_error':True,
                    'lmax':4001,
                    'variant':'act_baseline'},packages_path='/Users/zhiyulu/Documents/Science/Cosmology_data/ACT_dr6_likelihood')
# Out:
# Loading ACT DR6 lensing likelihood v1.2...

# %%
c.lens_only
# Out:
# True

# %%
c.stop_at_error
# Out:
# True

# %%
c.lmax
# Out:
# 4001

# %%
c.loglike
# Out:
# <bound method ACTDR6LensLike.loglike of act_dr6_lenslike>
