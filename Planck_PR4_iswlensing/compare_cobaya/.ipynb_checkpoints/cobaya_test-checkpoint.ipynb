# %%
from cobaya import get_model

# %%
params = {'logA': 3.044,
 'n_s': 0.965,
 'h': 0.675,
 'omega_b': 0.02235,
 'omega_cdm': 0.120,
 'tau_reio': 0.0543,
         }

mode=get_model('class_lensingTT.yaml')
mode.logposterior(params)
# Out:
# [model] *WARNING* Ignored blocks/options: ['sampler', 'output']
# [classy] `classy` module loaded successfully from /Users/zhiyulu/Install/anaconda3/lib/python3.11/site-packages
# ISWlensing: tt tp pp Nbins  98 98 98
# ISWlensing: lmins  2 2 2
# ISWlensing: lmaxs  99 99 99
# ISWlensing: OK for resp calc
# ISWlensing: Rfid test ok
# ISWlensing: rebinning using inverse covariance weighting  83 7 2
# LogPosterior(logpost=1.64729261971898, logpriors=[2.7894037928589683], loglikes=array([-1.14211117]), derived=[2.0989031673191437e-09, 0.31384172488986367, 0.14299413590294416, 0.6860787971858595, 0.24529383108121505, 7.6847991943359375, 0.8112112734793878, 0.9873749186381179, 0.45445335974081924, 0.6071718773892086, 2.098903167319144, 1.8829033242359754, 13.785194922202777, 147.1192099219605], finite=False)

# %%
params = {'logA': 3.044,
 'ns': 0.965,
 'H0':67.5,
 'ombh2': 0.02235,
 'omch2': 0.120,
 'tau': 0.0543,
         }

mode=get_model('camb_lensingTT.yaml')
mode.logposterior(params)
# Out:
# [model] *WARNING* Ignored blocks/options: ['sampler', 'output']
# [camb] `camb` module loaded successfully from /Users/zhiyulu/Install/anaconda3/lib/python3.11/site-packages/camb
# ISWlensing: tt tp pp Nbins  98 98 98
# ISWlensing: lmins  2 2 2
# ISWlensing: lmaxs  99 99 99
# ISWlensing: OK for resp calc
# ISWlensing: Rfid test ok
# ISWlensing: rebinning using inverse covariance weighting  83 7 2
# [root] *WARNING* Using kmax=1.2 with Halofit non-linear models may give inaccurate results
# LogPosterior(logpost=-2.9442413544317576, logpriors=[-1.9211269087869498], loglikes=array([-1.02311445]), derived=[2.0989031673191437e-09, 0.31384332855006886, 0.14299486657062513, 0.6860773801156582, 0.2458469475109757, 0.24717857618732944, 2.4518527209385357, 7.688141066123867, 0.8116405479998009, 0.9878974149452122, 0.4546950077927723, 0.6074939549474542, 2.098903167319144, 1.8829033242359754, 13.784898029874716, 147.12345578688982], finite=False)
