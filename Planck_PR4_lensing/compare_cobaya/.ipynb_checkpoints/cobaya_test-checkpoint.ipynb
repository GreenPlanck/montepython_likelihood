# %%
from cobaya import get_model

# %%
params = {'logA': 3.044,
 'n_s': 0.965,
 'h': 0.675,
 'omega_b': 0.02235,
 'omega_cdm': 0.120,
 'tau_reio': 0.0543,
 'A_planck':1.
         }

# %%
mode=get_model('pr4lens.yaml')
mode.logposterior(params)
# Out:
# [model] *WARNING* Ignored blocks/options: ['sampler', 'output']
# [classy] `classy` module loaded successfully from /Users/zhiyulu/Install/anaconda3/lib/python3.11/site-packages
# LogPosterior(logpost=3.6013539141771096, logpriors=[7.8619298067622765], loglikes=array([-4.26057589]), derived=[2.0989031673191437e-09, 0.31384172488986367, 0.14299413590294416, 0.6860787971858595, 0.24529383108121505, 7.6847991943359375, 0.8112133038592231, 0.9873773899377536, 0.45445449719165093, 0.607173397079056, 2.098903167319144, 1.8829033242359754, 13.785194922202777, 147.1192099219605, 8.521151785170334], finite=False)

# %%
params = {'logA': 3.044,
 'n_s': 0.965,
 'h': 0.675,
 'omega_b': 0.02235,
 'omega_cdm': 0.120,
 'tau_reio': 0.0543,
         }
mode=get_model('pr4lensmarg.yaml')
mode.logposterior(params)
# Out:
# [model] *WARNING* Ignored blocks/options: ['sampler', 'output']
# [classy] `classy` module loaded successfully from /Users/zhiyulu/Install/anaconda3/lib/python3.11/site-packages
# LogPosterior(logpost=-1.4400439507653577, logpriors=[2.7894037928589683], loglikes=array([-4.22944774]), derived=[2.0989031673191437e-09, 0.31384172488986367, 0.14299413590294416, 0.6860787971858595, 0.24529383108121505, 7.6847991943359375, 0.8112133038592231, 0.9873773899377536, 0.45445449719165093, 0.607173397079056, 2.098903167319144, 1.8829033242359754, 13.785194922202777, 147.1192099219605, 8.458895487248652], finite=False)
