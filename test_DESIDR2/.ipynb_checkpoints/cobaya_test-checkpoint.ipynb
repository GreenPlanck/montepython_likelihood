# %%
from cobaya import get_model

# %%
import cobaya
cobaya?
# Out:
# Type:        module
# String form: <module 'cobaya' from '/Users/zhiyulu/Documents/Science/Cosmology_packages/cobaya-master/cobaya/__init__.py'>
# File:        ~/Documents/Science/Cosmology_packages/cobaya-master/cobaya/__init__.py
# Docstring:   <no docstring>

# %%
# random_point = mode.prior.sample(ignore_external=True)[0]
# sampled_params_names = mode.parameterization.sampled_params()
# random_point_dict = dict(zip(sampled_params_names, random_point))
# random_point_dict

# %%
params = {'logA': 3.044,
 'n_s': 0.965,
 'h': 0.675,
 'omega_b': 0.02235,
 'omega_cdm': 0.120,
 'tau_reio': 0.0543}

# %%
mode=get_model('desi_dr2.yaml')
mode.logposterior(params)
# Out:
# [model] *WARNING* Ignored blocks/options: ['sampler', 'output']
# [classy] `classy` module loaded successfully from /Users/zhiyulu/Install/anaconda3/lib/python3.11/site-packages/classy-3.2.3-py3.11-macosx-11.0-arm64.egg
# [bao.desi_dr2.desi_bao_all] Initialized.
# LogPosterior(logpost=-10.242234573097823, logpriors=[2.7894037928589683], loglikes=array([-13.03163837]), derived=[2.0989031673191437e-09, 0.31384172488986367, 0.14299413590294416, 0.2453874077290285, 7.6847991943359375, 0.8112613998913561, 0.9874359305638108, 0.4544814413480102, 0.6072093957875059, 2.098903167319144, 1.8829033242359754, 13.785194922202777, 147.1189769457071, 26.063276731913582], finite=False)
